# %% [markdown]
# # Online News Popularion Dataset
#
# ### Load the dataset from a local file

# %%
import pandas as pd

# %%
news = pd.read_csv("OnlineNewsPopularity.csv", encoding = "unicode_escape")

# %% [markdown]
# ### Display the data

# %%
news.head(20)
# view some of the rows
# Out:
#                                                   URL   TIME  n_words_title  \
# 0   http://mashable.com/2013/01/07/amazon-instant-...  731.0           12.0
# 1   http://mashable.com/2013/01/07/ap-samsung-spon...  731.0            9.0
# 2   http://mashable.com/2013/01/07/apple-40-billio...  731.0            9.0
# 3   http://mashable.com/2013/01/07/astronaut-notre...  731.0            9.0
# 4    http://mashable.com/2013/01/07/att-u-verse-apps/  731.0           13.0
# 5    http://mashable.com/2013/01/07/beewi-smart-toys/  731.0           10.0
# 6   http://mashable.com/2013/01/07/bodymedia-armba...  731.0            8.0
# 7    http://mashable.com/2013/01/07/canon-poweshot-n/  731.0           12.0
# 8   http://mashable.com/2013/01/07/car-of-the-futu...  731.0           11.0
# 9   http://mashable.com/2013/01/07/chuck-hagel-web...  731.0           10.0
# 10  http://mashable.com/2013/01/07/cosmic-events-d...  731.0            9.0
# ...

# %%
news.columns
#view all of the columns title
# Out:
# Index(['url', ' timedelta', ' n_tokens_title', ' n_tokens_content',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
#        ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
#        ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
#        ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess',
#        ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
#        ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
#        ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
# ...

# %%
news.columns = ["URL", "TIME", "n_words_title", "n_words_content", "n_uniqueWords_content", "n_nonStopWords_content","n_nonStopUniqueWords_content","num_link", "num_selfLink", "num_images", "num_videos", "avg_wrod_length", "num_keywords",
       ' data_channel_is_lifestyle',' data_channel_is_entertainment', ' data_channel_is_bus', ' data_channel_is_socmed', ' data_channel_is_tech',' data_channel_is_world',
       ' kw_min_worst', ' kw_max_worst', ' kw_avg_worst',' kw_min_best', ' kw_max_best', ' kw_avg_best', ' kw_min_best', ' kw_max_avg', ' kw_avg_avg',
       ' self_reference_min_shares', ' self_reference_max_shares', ' self_reference_avg_sharess',
       ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
       ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
       ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
       ' LDA_03', ' LDA_04', ' global_subjectivity',
       ' global_sentiment_polarity', ' global_rate_positive_words',
       ' global_rate_negative_words', ' rate_positive_words',
       ' rate_negative_words', ' avg_positive_polarity',
       ' min_positive_polarity', ' max_positive_polarity',
       ' avg_negative_polarity', ' min_negative_polarity',
       ' max_negative_polarity', ' title_subjectivity',
       ' title_sentiment_polarity', ' abs_title_subjectivity',
       ' abs_title_sentiment_polarity', ' shares']

# %% [markdown]
# ## Simple statistics of the data

# %%
news.describe()
# Out:
#                TIME  n_words_title  n_words_content  n_uniqueWords_content  \
# count  39644.000000   39644.000000     39644.000000           39644.000000
# mean     354.530471      10.398749       546.514731               0.548216
# std      214.163767       2.114037       471.107508               3.520708
# min        8.000000       2.000000         0.000000               0.000000
# 25%      164.000000       9.000000       246.000000               0.470870
# 50%      339.000000      10.000000       409.000000               0.539226
# 75%      542.000000      12.000000       716.000000               0.608696
# max      731.000000      23.000000      8474.000000             701.000000
#
#        n_nonStopWords_content  n_nonStopUniqueWords_content      num_link  \
# count            39644.000000                  39644.000000  39644.000000
# mean                 0.996469                      0.689175     10.883690
# ...

# %%
news.n_words_title.describe()
# Out:
# count    39644.000000
# mean        10.398749
# std          2.114037
# min          2.000000
# 25%          9.000000
# 50%         10.000000
# 75%         12.000000
# max         23.000000
# Name: n_words_title, dtype: float64

# %%
(news.n_words_title == 9.0).count()
# Out:
# 39644

# %%
news.num_selfLink.describe()
# Out:
# count    39644.000000
# mean         3.293638
# std          3.855141
# min          0.000000
# 25%          1.000000
# 50%          3.000000
# 75%          4.000000
# max        116.000000
# Name: num_selfLink, dtype: float64

# %%
(news.num_selfLink == 2.0).describe()
# Out:
# count     39644
# unique        2
# top       False
# freq      32020
# Name: num_selfLink, dtype: object

# %%
news.n_words_title.describe()
# Out:
# count    39644.000000
# mean        10.398749
# std          2.114037
# min          2.000000
# 25%          9.000000
# 50%         10.000000
# 75%         12.000000
# max         23.000000
# Name: n_words_title, dtype: float64

# %%
news.n_words_content.describe()
# Out:
# count    39644.000000
# mean       546.514731
# std        471.107508
# min          0.000000
# 25%        246.000000
# 50%        409.000000
# 75%        716.000000
# max       8474.000000
# Name: n_words_content, dtype: float64

# %%
(news.n_words_content >= 409.00).describe()
# Out:
# count     39644
# unique        2
# top        True
# freq      19867
# Name: n_words_content, dtype: object

# %% [markdown]
# ## Display histograms

# %%
# %matplotlib inline

# %%
histogram2 = news.hist('n_words_title')

# %%
histogram = news.hist('n_words_content')
