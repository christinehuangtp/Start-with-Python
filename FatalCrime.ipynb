# %% [markdown]
# ## Fatal Crime Dataset
# ### Load the data set from csv. file

# %%
import pandas as pd

# %%
crime = pd.read_csv('crime.csv', encoding='unicode_escape')

# %% [markdown]
# ### Display the data

# %%
crime.head(40)
# Out:
#      id                              name        date   manner_of_death  \
# 0     3                        Tim Elliot  2015-01-02              shot
# 1     4                  Lewis Lee Lembke  2015-01-02              shot
# 2     5                John Paul Quintero  2015-01-03  shot and Tasered
# 3     8                   Matthew Hoffman  2015-01-04              shot
# 4     9                 Michael Rodriguez  2015-01-04              shot
# 5    11                 Kenneth Joe Brown  2015-01-04              shot
# 6    13               Kenneth Arnold Buck  2015-01-05              shot
# 7    15                     Brock Nichols  2015-01-06              shot
# 8    16                     Autumn Steele  2015-01-06              shot
# 9    17                   Leslie Sapp III  2015-01-06              shot
# 10   19                    Patrick Wetter  2015-01-06  shot and Tasered
# 11   21                         Ron Sneed  2015-01-07              shot
# ...

# %%
crime.tail()
# Out:
#         id                 name        date manner_of_death armed   age  \
# 2137  2382   James Leroy Marker  2017-02-26            shot   gun  66.0
# 2138  2378      Joey J. Bridges  2017-02-27            shot   gun  27.0
# 2139  2391       Shawn M. Igers  2017-02-27            shot   gun  40.0
# 2140  2393           Earl Riley  2017-02-28            shot   gun  25.0
# 2141  2394  Christopher Redding  2017-02-28            shot   gun  20.0
#
#      gender race         city state  signs_of_mental_illness threat_level  \
# 2137      M    W  Floral City    FL                    False        other
# 2138      M    W       Shelby    NC                     True       attack
# 2139      M    W      Corning    WI                    False       attack
# 2140      M    B      Houston    TX                    False       attack
# 2141      M    B      Orlando    FL                    False       attack
#
#              flee  body_camera
# 2137          Car        False
# ...

# %% [markdown]
# ## Simple statistics of the data

# %%
crime.describe()
# Out:
#                id          age
# count  2142.00000  2099.000000
# mean   1232.21662    36.484516
# std     670.62817    12.874000
# min       3.00000     6.000000
# 25%     664.50000    26.000000
# 50%    1231.50000    34.000000
# 75%    1811.75000    45.000000
# max    2394.00000    86.000000

# %%
crime.manner_of_death.describe()
# Out:
# count     2142
# unique       2
# top       shot
# freq      1992
# Name: manner_of_death, dtype: object

# %%
crime.age.describe()
# Out:
# count    2099.000000
# mean       36.484516
# std        12.874000
# min         6.000000
# 25%        26.000000
# 50%        34.000000
# 75%        45.000000
# max        86.000000
# Name: age, dtype: float64

# %%
(crime.armed == 'gun').describe()
# Out:
# count     2142
# unique       2
# top       True
# freq      1173
# Name: armed, dtype: object

# %% [markdown]
# ## Display histograms

# %%
# %matplotlib inline

# %%
histogram = crime.hist('age')
